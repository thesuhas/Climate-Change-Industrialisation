# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import datetime as dt
import numpy as np
import copy
import seaborn as sns
from pandas.plotting import scatter_matrix

# %% [markdown]
# ## Reading excel file

# %%
xls = pd.ExcelFile('data.xlsx')

# %% [markdown]
# ## Reading individual Sheets

# %%
# Industrialisation DataFrame
ind = pd.read_excel(xls, 'industrialisation')
ind.head()
ind.shape
# Out:
# (2840, 30)

# %%
# CO2 dataframe
co2 = pd.read_excel(xls, 'Co2')
co2
# Out:
#             Entity Code  Year  Annual CO2 emissions (tonnes )
# 0      Afghanistan  AFG  1949                        14656.00
# 1      Afghanistan  AFG  1950                        84272.00
# 2      Afghanistan  AFG  1951                        91600.00
# 3      Afghanistan  AFG  1952                        91600.00
# 4      Afghanistan  AFG  1953                       106256.00
# ...            ...  ...   ...                             ...
# 20848     Zimbabwe  ZWE  2013                     11536239.29
# 20849     Zimbabwe  ZWE  2014                     11866348.41
# 20850     Zimbabwe  ZWE  2015                     10907603.94
# 20851     Zimbabwe  ZWE  2016                      9932649.88
# 20852     Zimbabwe  ZWE  2017                     10397718.47
#
# [20853 rows x 4 columns]

# %%
co2.shape
# Out:
# (20853, 4)

# %%
# Global Temps Dataframe
gltemp = pd.read_excel(xls, 'GlobalLandTemperaturesByCity')
gltemp.head()
gltemp.shape
# Out:
# (1048575, 7)

# %% [markdown]
# ## Cleaning the DFs

# %% [markdown]
# ### Cleaning Global Temps By City

# %%
gltemp.isna().sum()
# Out:
# dt                                   0
# AverageTemperature               47547
# AverageTemperatureUncertainty    47547
# City                                 0
# Country                              0
# Latitude                             0
# Longitude                            0
# dtype: int64

# %%
gltemp.iloc[798583]['dt']
# Out:
# datetime.datetime(1900, 7, 1, 0, 0)

# %%
gltemp = gltemp.dropna()

# %%
gltemp.isna().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# City                             0
# Country                          0
# Latitude                         0
# Longitude                        0
# dtype: int64

# %%
print(gltemp.iloc[798580])
# Out:
# dt                               1987-07-01 00:00:00
# AverageTemperature                             22.97
# AverageTemperatureUncertainty                  0.207
# City                                           Benxi
# Country                                        China
# Latitude                                      40.99N
# Longitude                                    123.55E
# Name: 836224, dtype: object

# %%
gltemp = gltemp.reset_index()

# %%
del gltemp['index']

# %%
gltemp.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0  1743-11-01               6.068                          1.737  Ã…rhus
# 1  1744-04-01               5.788                          3.624  Ã…rhus
# 2  1744-05-01              10.644                          1.283  Ã…rhus
# 3  1744-06-01              14.051                          1.347  Ã…rhus
# 4  1744-07-01              16.082                          1.396  Ã…rhus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
gltemp['dt'] = pd.to_datetime(gltemp['dt'])

# %%
gltemp.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty    City  \
# 0 1743-11-01               6.068                          1.737  Ã…rhus
# 1 1744-04-01               5.788                          3.624  Ã…rhus
# 2 1744-05-01              10.644                          1.283  Ã…rhus
# 3 1744-06-01              14.051                          1.347  Ã…rhus
# 4 1744-07-01              16.082                          1.396  Ã…rhus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
gltemp = gltemp[gltemp['dt'] > pd.Timestamp(year=1989, day=31, month=12)]

# %%
gltemp.head()
gltemp.shape
# Out:
# (119879, 7)

# %%
gltemp = gltemp.reset_index(drop=True)

# %%
gltemp['dt'] = gltemp['dt'].dt.year
gltemp
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0       1990               4.267                          0.459   Ã…rhus
# 1       1990               5.895                          0.460   Ã…rhus
# 2       1990               6.565                          0.299   Ã…rhus
# 3       1990               8.068                          0.222   Ã…rhus
# 4       1990              12.944                          0.287   Ã…rhus
# ...      ...                 ...                            ...      ...
# 119874  2013              27.745                          0.241  Bontang
# 119875  2013              27.795                          0.258  Bontang
# 119876  2013              28.220                          0.292  Bontang
# 119877  2013              27.127                          0.231  Bontang
# 119878  2013              26.862                          0.509  Bontang
#
#           Country Latitude Longitude
# 0         Denmark   57.05N    10.33E
# 1         Denmark   57.05N    10.33E
# 2         Denmark   57.05N    10.33E
# 3         Denmark   57.05N    10.33E
# 4         Denmark   57.05N    10.33E
# ...           ...      ...       ...
# 119874  Indonesia    0.80N   118.13E
# 119875  Indonesia    0.80N   118.13E
# 119876  Indonesia    0.80N   118.13E
# 119877  Indonesia    0.80N   118.13E
# 119878  Indonesia    0.80N   118.13E
#
# [119879 rows x 7 columns]

# %%
# List of countries being analysed
countries = ['India', 'China', 'United States', 'United Kingdom', 'Japan', 'Germany']

country = gltemp[gltemp['Country'].isin(countries)]

# %%
country = country.reset_index(drop=True)
country
# Out:
#          dt  AverageTemperature  AverageTemperatureUncertainty      City  \
# 0      1990             -13.093                          0.522  ÃœrÃ¼mqi
# 1      1990             -10.704                          0.399  ÃœrÃ¼mqi
# 2      1990              -0.075                          0.469  ÃœrÃ¼mqi
# 3      1990               9.557                          0.249  ÃœrÃ¼mqi
# 4      1990              17.972                          0.285  ÃœrÃ¼mqi
# ...     ...                 ...                            ...       ...
# 46026  2013               8.374                          0.199      Bonn
# 46027  2013              11.463                          0.235      Bonn
# 46028  2013              15.589                          0.247      Bonn
# 46029  2013              19.869                          0.280      Bonn
# 46030  2013              18.098                          0.338      Bonn
#
#        Country Latitude Longitude
# 0        China   44.20N    87.20E
# 1        China   44.20N    87.20E
# 2        China   44.20N    87.20E
# 3        China   44.20N    87.20E
# 4        China   44.20N    87.20E
# ...        ...      ...       ...
# 46026  Germany   50.63N     6.34E
# 46027  Germany   50.63N     6.34E
# 46028  Germany   50.63N     6.34E
# 46029  Germany   50.63N     6.34E
# 46030  Germany   50.63N     6.34E
#
# [46031 rows x 7 columns]

# %%
grouped = country.groupby(['dt', 'Country']).mean()

# %%
grouped
# Out:
#                      AverageTemperature  AverageTemperatureUncertainty
# dt   Country
# 1990 China                    10.930208                       0.331760
#      Germany                   9.785250                       0.289024
#      India                    26.033152                       0.395594
#      Japan                    14.147424                       0.269750
#      United Kingdom           10.101881                       0.279119
# ...                                 ...                            ...
# 2013 Germany                   9.141339                       0.279643
#      India                    27.179701                       0.512657
#      Japan                    13.804729                       0.450458
#      United Kingdom            9.156000                       0.434500
#      United States            14.929293                       0.387619
#
# [144 rows x 2 columns]

# %%
temp = grouped.reset_index()
temp
# Out:
#        dt         Country  AverageTemperature  AverageTemperatureUncertainty
# 0    1990           China           10.930208                       0.331760
# 1    1990         Germany            9.785250                       0.289024
# 2    1990           India           26.033152                       0.395594
# 3    1990           Japan           14.147424                       0.269750
# 4    1990  United Kingdom           10.101881                       0.279119
# ..    ...             ...                 ...                            ...
# 139  2013         Germany            9.141339                       0.279643
# 140  2013           India           27.179701                       0.512657
# 141  2013           Japan           13.804729                       0.450458
# 142  2013  United Kingdom            9.156000                       0.434500
# 143  2013   United States           14.929293                       0.387619
#
# [144 rows x 4 columns]

# %% [markdown]
# ### Cleaning the co2 dataset

# %%
country = co2[co2['Entity'].isin(countries)]

# %%
co2 = country.reset_index(drop=True)

# %%
co2
# Out:
#              Entity Code  Year  Annual CO2 emissions (tonnes )
# 0             China  CHN  1751                    0.000000e+00
# 1             China  CHN  1752                    0.000000e+00
# 2             China  CHN  1753                    0.000000e+00
# 3             China  CHN  1754                    0.000000e+00
# 4             China  CHN  1755                    0.000000e+00
# ...             ...  ...   ...                             ...
# 1415  United States  USA  2013                    5.519613e+09
# 1416  United States  USA  2014                    5.568759e+09
# 1417  United States  USA  2015                    5.420804e+09
# 1418  United States  USA  2016                    5.310861e+09
# 1419  United States  USA  2017                    5.269530e+09
#
# [1420 rows x 4 columns]

# %%
co2 = co2[co2['Year'] > 1989]
co2 = co2[co2['Year'] < 2014]

# %%
del co2['Code']
co2
# Out:
#              Entity  Year  Annual CO2 emissions (tonnes )
# 226           China  1990                    2.420302e+09
# 227           China  1991                    2.538924e+09
# 228           China  1992                    2.657112e+09
# 229           China  1993                    2.835795e+09
# 230           China  1994                    3.010242e+09
# ...             ...   ...                             ...
# 1411  United States  2009                    5.495395e+09
# 1412  United States  2010                    5.701076e+09
# 1413  United States  2011                    5.570707e+09
# 1414  United States  2012                    5.366730e+09
# 1415  United States  2013                    5.519613e+09
#
# [144 rows x 3 columns]

# %%
co2_g = co2.groupby(['Year', 'Entity']).mean()
co2_g
# Out:
#                      Annual CO2 emissions (tonnes )
# Year Entity
# 1990 China                             2.420302e+09
#      Germany                           1.012902e+09
#      India                             6.165791e+08
#      Japan                             1.155263e+09
#      United Kingdom                    6.010676e+08
# ...                                             ...
# 2013 Germany                           8.326430e+08
#      India                             1.997879e+09
#      Japan                             1.314070e+09
#      United Kingdom                    4.777326e+08
#      United States                     5.519613e+09
#
# [144 rows x 1 columns]

# %% [markdown]
# # industrialization dataframe

# %%
country = ind[ind['Country Name'].isin(countries)]

# %%
ind = country.reset_index(drop=True)

# %%
ind
# Out:
#     Country ISO3   Country Name  Indicator Id  \
# 0            CHN          China          3786
# 1            CHN          China          3787
# 2            CHN          China          3788
# 3            CHN          China          3789
# 4            CHN          China          3790
# ..           ...            ...           ...
# 115          USA  United States          3802
# 116          USA  United States          3803
# 117          USA  United States          3804
# 118          USA  United States          3805
# 119          USA  United States          3806
#
#                                              Indicator Subindicator Type  \
# 0             Competitive Industrial Performance Score             Value
# 1              Competitive Industrial Performance Rank              Rank
# 2          Competitive Industrial Performance Quintile             Value
# 3      Impact of a country on World Manufactures Trade             Value
# 4           Share in world manufacturing exports index             Value
# ..                                                 ...               ...
# 115                    Manufactured Exports per capita             Value
# 116              Manufactured Exports per capita index             Value
# 117                    Industrial export quality index             Value
# 118        Manufactured Exports share in total exports             Value
# 119  Share of manufactured exports in total exports...             Value
#
#             1990         1991         1992         1993         1994  ...  \
# 0       0.088960     0.093291     0.100299     0.110058     0.123855  ...
# 1      32.000000    33.000000    31.000000    30.000000    27.000000  ...
# 2       0.700000     0.700000     0.700000     0.700000     0.900000  ...
# 3       0.025118     0.025118     0.025118     0.028023     0.032752  ...
# 4       0.170583     0.170583     0.181641     0.215762     0.258881  ...
# ..           ...          ...          ...          ...          ...  ...
# 115  1200.451820  1292.108117  1357.289521  1390.028964  1534.043630  ...
# 116     0.074705     0.080411     0.084469     0.086507     0.094642  ...
# 117     0.848574     0.857247     0.857395     0.856469     0.861043  ...
# 118     0.815927     0.828391     0.829481     0.830081     0.843921  ...
# 119     0.825212     0.839491     0.844595     0.844535     0.859058  ...
#
#             2005         2006         2007         2008         2009  \
# 0       0.256939     0.277764     0.297416     0.313759     0.341954
# 1      17.000000    16.000000    12.000000     9.000000     6.000000
# 2       0.900000     0.900000     0.900000     0.900000     0.900000
# 3       0.093232     0.103558     0.114255     0.119714     0.129652
# 4       0.810990     0.909162     0.999802     1.000000     1.000000
# ..           ...          ...          ...          ...          ...
# 115  2321.691730  2657.235782  2920.815071  3178.236048  2292.570345
# 116     0.082268     0.087489     0.081631     0.082869     0.076393
# 117     0.881568     0.878403     0.872286     0.859803     0.794639
# 118     0.861052     0.860435     0.848114     0.833288     0.757616
# 119     0.878989     0.878527     0.865808     0.853507     0.775502
#
#             2010         2011         2012         2013         2014
# 0       0.360612     0.362264     0.376657     0.378066     0.356159
# 1       6.000000     6.000000     5.000000     5.000000     5.000000
# 2       0.900000     0.900000     0.900000     0.900000     0.900000
# 3       0.140085     0.143447     0.156094     0.162601     0.164545
# 4       1.000000     1.000000     1.000000     1.000000     1.000000
# ..           ...          ...          ...          ...          ...
# 115  2770.181976  3137.032070  3225.220141  3231.862861  3269.323814
# 116     0.085108     0.083214     0.090452     0.080208     0.052594
# 117     0.781659     0.744058     0.748143     0.741225     0.708612
# 118     0.770793     0.760074     0.757452     0.754638     0.753809
# 119     0.789266     0.778268     0.775191     0.763941     0.752419
#
# [120 rows x 30 columns]

# %%
ind.isna().sum()
# Out:
# Country ISO3         0
# Country Name         0
# Indicator Id         0
# Indicator            0
# Subindicator Type    0
# 1990                 0
# 1991                 0
# 1992                 0
# 1993                 0
# 1994                 0
# 1995                 0
# 1996                 0
# 1997                 0
# 1998                 0
# 1999                 0
# 2000                 0
# 2001                 0
# 2002                 0
# 2003                 0
# 2004                 0
# 2005                 0
# 2006                 0
# 2007                 0
# 2008                 0
# 2009                 0
# 2010                 0
# 2011                 0
# 2012                 0
# 2013                 0
# 2014                 0
# dtype: int64

# %%
del ind['Country ISO3']
del ind['Indicator Id']
#del ind['Subindicator Type']
ind
# Out:
#       Country Name                                          Indicator  \
# 0            China           Competitive Industrial Performance Score
# 1            China            Competitive Industrial Performance Rank
# 2            China        Competitive Industrial Performance Quintile
# 3            China    Impact of a country on World Manufactures Trade
# 4            China         Share in world manufacturing exports index
# ..             ...                                                ...
# 115  United States                    Manufactured Exports per capita
# 116  United States              Manufactured Exports per capita index
# 117  United States                    Industrial export quality index
# 118  United States        Manufactured Exports share in total exports
# 119  United States  Share of manufactured exports in total exports...
#
#     Subindicator Type         1990         1991         1992         1993  \
# 0               Value     0.088960     0.093291     0.100299     0.110058
# 1                Rank    32.000000    33.000000    31.000000    30.000000
# 2               Value     0.700000     0.700000     0.700000     0.700000
# 3               Value     0.025118     0.025118     0.025118     0.028023
# 4               Value     0.170583     0.170583     0.181641     0.215762
# ..                ...          ...          ...          ...          ...
# 115             Value  1200.451820  1292.108117  1357.289521  1390.028964
# 116             Value     0.074705     0.080411     0.084469     0.086507
# 117             Value     0.848574     0.857247     0.857395     0.856469
# 118             Value     0.815927     0.828391     0.829481     0.830081
# 119             Value     0.825212     0.839491     0.844595     0.844535
#
#             1994         1995         1996  ...         2005         2006  \
# 0       0.123855     0.133536     0.136619  ...     0.256939     0.277764
# 1      27.000000    27.000000    25.000000  ...    17.000000    16.000000
# 2       0.900000     0.900000     0.900000  ...     0.900000     0.900000
# 3       0.032752     0.034336     0.033401  ...     0.093232     0.103558
# 4       0.258881     0.288280     0.276394  ...     0.810990     0.909162
# ..           ...          ...          ...  ...          ...          ...
# 115  1534.043630  1709.605923  1796.294990  ...  2321.691730  2657.235782
# 116     0.094642     0.092036     0.093353  ...     0.082268     0.087489
# 117     0.861043     0.856583     0.861895  ...     0.881568     0.878403
# 118     0.843921     0.838594     0.836965  ...     0.861052     0.860435
# 119     0.859058     0.853696     0.850239  ...     0.878989     0.878527
#
#             2007         2008         2009         2010         2011  \
# 0       0.297416     0.313759     0.341954     0.360612     0.362264
# 1      12.000000     9.000000     6.000000     6.000000     6.000000
# 2       0.900000     0.900000     0.900000     0.900000     0.900000
# 3       0.114255     0.119714     0.129652     0.140085     0.143447
# 4       0.999802     1.000000     1.000000     1.000000     1.000000
# ..           ...          ...          ...          ...          ...
# 115  2920.815071  3178.236048  2292.570345  2770.181976  3137.032070
# 116     0.081631     0.082869     0.076393     0.085108     0.083214
# 117     0.872286     0.859803     0.794639     0.781659     0.744058
# 118     0.848114     0.833288     0.757616     0.770793     0.760074
# 119     0.865808     0.853507     0.775502     0.789266     0.778268
#
#             2012         2013         2014
# 0       0.376657     0.378066     0.356159
# 1       5.000000     5.000000     5.000000
# 2       0.900000     0.900000     0.900000
# 3       0.156094     0.162601     0.164545
# 4       1.000000     1.000000     1.000000
# ..           ...          ...          ...
# 115  3225.220141  3231.862861  3269.323814
# 116     0.090452     0.080208     0.052594
# 117     0.748143     0.741225     0.708612
# 118     0.757452     0.754638     0.753809
# 119     0.775191     0.763941     0.752419
#
# [120 rows x 28 columns]

# %%
ind_g = ind.groupby(['Country Name', 'Indicator', 'Subindicator Type']).mean()
ind_g
# Out:
#                                                                                          1990  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.700000
#               Competitive Industrial Performance Rank            Rank               32.000000
#               Competitive Industrial Performance Score           Value               0.088960
#               Impact of a country on World Manufactures Trade    Value               0.025118
#               Impact of a country on World Manufacturing Valu... Value               0.033536
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.261164
#               Share of Medium and High-Tech Activities in Man... Value               0.871935
#               Share of Medium and High-Tech Activities in Tot... Value               0.747063
#               Share of manufactured exports in total exports ... Value               0.825212
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1991  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.700000
#               Competitive Industrial Performance Rank            Rank               33.000000
#               Competitive Industrial Performance Score           Value               0.093291
#               Impact of a country on World Manufactures Trade    Value               0.025118
#               Impact of a country on World Manufacturing Valu... Value               0.037863
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.251449
#               Share of Medium and High-Tech Activities in Man... Value               0.875003
#               Share of Medium and High-Tech Activities in Tot... Value               0.705029
#               Share of manufactured exports in total exports ... Value               0.839491
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1992  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.700000
#               Competitive Industrial Performance Rank            Rank               31.000000
#               Competitive Industrial Performance Score           Value               0.100299
#               Impact of a country on World Manufactures Trade    Value               0.025118
#               Impact of a country on World Manufacturing Valu... Value               0.045071
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.245930
#               Share of Medium and High-Tech Activities in Man... Value               0.870194
#               Share of Medium and High-Tech Activities in Tot... Value               0.688031
#               Share of manufactured exports in total exports ... Value               0.844595
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1993  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.700000
#               Competitive Industrial Performance Rank            Rank               30.000000
#               Competitive Industrial Performance Score           Value               0.110058
#               Impact of a country on World Manufactures Trade    Value               0.028023
#               Impact of a country on World Manufacturing Valu... Value               0.053268
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.256450
#               Share of Medium and High-Tech Activities in Man... Value               0.868404
#               Share of Medium and High-Tech Activities in Tot... Value               0.684693
#               Share of manufactured exports in total exports ... Value               0.844535
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1994  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               27.000000
#               Competitive Industrial Performance Score           Value               0.123855
#               Impact of a country on World Manufactures Trade    Value               0.032752
#               Impact of a country on World Manufacturing Valu... Value               0.059694
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.262437
#               Share of Medium and High-Tech Activities in Man... Value               0.863029
#               Share of Medium and High-Tech Activities in Tot... Value               0.677398
#               Share of manufactured exports in total exports ... Value               0.859058
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1995  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               27.000000
#               Competitive Industrial Performance Score           Value               0.133536
#               Impact of a country on World Manufactures Trade    Value               0.034336
#               Impact of a country on World Manufacturing Valu... Value               0.063942
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.275881
#               Share of Medium and High-Tech Activities in Man... Value               0.859471
#               Share of Medium and High-Tech Activities in Tot... Value               0.658053
#               Share of manufactured exports in total exports ... Value               0.853696
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1996  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               25.000000
#               Competitive Industrial Performance Score           Value               0.136619
#               Impact of a country on World Manufactures Trade    Value               0.033401
#               Impact of a country on World Manufacturing Valu... Value               0.069088
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.270509
#               Share of Medium and High-Tech Activities in Man... Value               0.873552
#               Share of Medium and High-Tech Activities in Tot... Value               0.512592
#               Share of manufactured exports in total exports ... Value               0.850239
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1997  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               25.000000
#               Competitive Industrial Performance Score           Value               0.146228
#               Impact of a country on World Manufactures Trade    Value               0.038720
#               Impact of a country on World Manufacturing Valu... Value               0.072454
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.266787
#               Share of Medium and High-Tech Activities in Man... Value               0.887447
#               Share of Medium and High-Tech Activities in Tot... Value               0.691852
#               Share of manufactured exports in total exports ... Value               0.872466
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1998  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               24.000000
#               Competitive Industrial Performance Score           Value               0.154604
#               Impact of a country on World Manufactures Trade    Value               0.039177
#               Impact of a country on World Manufacturing Valu... Value               0.077378
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.267197
#               Share of Medium and High-Tech Activities in Man... Value               0.899430
#               Share of Medium and High-Tech Activities in Tot... Value               0.693995
#               Share of manufactured exports in total exports ... Value               0.867130
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          1999  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               23.000000
#               Competitive Industrial Performance Score           Value               0.159102
#               Impact of a country on World Manufactures Trade    Value               0.040507
#               Impact of a country on World Manufacturing Valu... Value               0.080796
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.282062
#               Share of Medium and High-Tech Activities in Man... Value               0.901308
#               Share of Medium and High-Tech Activities in Tot... Value               0.679035
#               Share of manufactured exports in total exports ... Value               0.874726
#               Share of world MVA index                           Value               1.000000
#
#                                                                                     ...  \
# Country Name  Indicator                                          Subindicator Type  ...
# China         Competitive Industrial Performance Quintile        Value              ...
#               Competitive Industrial Performance Rank            Rank               ...
#               Competitive Industrial Performance Score           Value              ...
#               Impact of a country on World Manufactures Trade    Value              ...
#               Impact of a country on World Manufacturing Valu... Value              ...
# ...                                                                                 ...
# United States Share of MVA in GDP index                          Value              ...
#               Share of Medium and High-Tech Activities in Man... Value              ...
#               Share of Medium and High-Tech Activities in Tot... Value              ...
#               Share of manufactured exports in total exports ... Value              ...
#               Share of world MVA index                           Value              ...
#
#                                                                                          2005  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               17.000000
#               Competitive Industrial Performance Score           Value               0.256939
#               Impact of a country on World Manufactures Trade    Value               0.093232
#               Impact of a country on World Manufacturing Valu... Value               0.117472
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.302844
#               Share of Medium and High-Tech Activities in Man... Value               0.884147
#               Share of Medium and High-Tech Activities in Tot... Value               0.594589
#               Share of manufactured exports in total exports ... Value               0.878989
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          2006  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               16.000000
#               Competitive Industrial Performance Score           Value               0.277764
#               Impact of a country on World Manufactures Trade    Value               0.103558
#               Impact of a country on World Manufacturing Valu... Value               0.126562
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.318679
#               Share of Medium and High-Tech Activities in Man... Value               0.878280
#               Share of Medium and High-Tech Activities in Tot... Value               0.583562
#               Share of manufactured exports in total exports ... Value               0.878527
#               Share of world MVA index                           Value               1.000000
#
#                                                                                          2007  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value               0.900000
#               Competitive Industrial Performance Rank            Rank               12.000000
#               Competitive Industrial Performance Score           Value               0.297416
#               Impact of a country on World Manufactures Trade    Value               0.114255
#               Impact of a country on World Manufacturing Valu... Value               0.138968
# ...                                                                                       ...
# United States Share of MVA in GDP index                          Value               0.327597
#               Share of Medium and High-Tech Activities in Man... Value               0.878765
#               Share of Medium and High-Tech Activities in Tot... Value               0.583439
#               Share of manufactured exports in total exports ... Value               0.865808
#               Share of world MVA index                           Value               1.000000
#
#                                                                                         2008  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               9.000000
#               Competitive Industrial Performance Score           Value              0.313759
#               Impact of a country on World Manufactures Trade    Value              0.119714
#               Impact of a country on World Manufacturing Valu... Value              0.153513
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.321915
#               Share of Medium and High-Tech Activities in Man... Value              0.866099
#               Share of Medium and High-Tech Activities in Tot... Value              0.581791
#               Share of manufactured exports in total exports ... Value              0.853507
#               Share of world MVA index                           Value              1.000000
#
#                                                                                         2009  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               6.000000
#               Competitive Industrial Performance Score           Value              0.341954
#               Impact of a country on World Manufactures Trade    Value              0.129652
#               Impact of a country on World Manufacturing Valu... Value              0.181587
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.324701
#               Share of Medium and High-Tech Activities in Man... Value              0.813776
#               Share of Medium and High-Tech Activities in Tot... Value              0.468649
#               Share of manufactured exports in total exports ... Value              0.775502
#               Share of world MVA index                           Value              1.000000
#
#                                                                                         2010  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               6.000000
#               Competitive Industrial Performance Score           Value              0.360612
#               Impact of a country on World Manufactures Trade    Value              0.140085
#               Impact of a country on World Manufacturing Valu... Value              0.186882
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.361265
#               Share of Medium and High-Tech Activities in Man... Value              0.774052
#               Share of Medium and High-Tech Activities in Tot... Value              0.553248
#               Share of manufactured exports in total exports ... Value              0.789266
#               Share of world MVA index                           Value              0.950980
#
#                                                                                         2011  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               6.000000
#               Competitive Industrial Performance Score           Value              0.362264
#               Impact of a country on World Manufactures Trade    Value              0.143447
#               Impact of a country on World Manufacturing Valu... Value              0.197423
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.362716
#               Share of Medium and High-Tech Activities in Man... Value              0.709849
#               Share of Medium and High-Tech Activities in Tot... Value              0.544531
#               Share of manufactured exports in total exports ... Value              0.778268
#               Share of world MVA index                           Value              0.868186
#
#                                                                                         2012  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               5.000000
#               Competitive Industrial Performance Score           Value              0.376657
#               Impact of a country on World Manufactures Trade    Value              0.156094
#               Impact of a country on World Manufacturing Valu... Value              0.210459
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.352499
#               Share of Medium and High-Tech Activities in Man... Value              0.721095
#               Share of Medium and High-Tech Activities in Tot... Value              0.548804
#               Share of manufactured exports in total exports ... Value              0.775191
#               Share of world MVA index                           Value              0.803095
#
#                                                                                         2013  \
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               5.000000
#               Competitive Industrial Performance Score           Value              0.378066
#               Impact of a country on World Manufactures Trade    Value              0.162601
#               Impact of a country on World Manufacturing Valu... Value              0.219102
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.351447
#               Share of Medium and High-Tech Activities in Man... Value              0.718509
#               Share of Medium and High-Tech Activities in Tot... Value              0.550147
#               Share of manufactured exports in total exports ... Value              0.763941
#               Share of world MVA index                           Value              0.761337
#
#                                                                                         2014
# Country Name  Indicator                                          Subindicator Type
# China         Competitive Industrial Performance Quintile        Value              0.900000
#               Competitive Industrial Performance Rank            Rank               5.000000
#               Competitive Industrial Performance Score           Value              0.356159
#               Impact of a country on World Manufactures Trade    Value              0.164545
#               Impact of a country on World Manufacturing Valu... Value              0.229128
# ...                                                                                      ...
# United States Share of MVA in GDP index                          Value              0.350219
#               Share of Medium and High-Tech Activities in Man... Value              0.664805
#               Share of Medium and High-Tech Activities in Tot... Value              0.583547
#               Share of manufactured exports in total exports ... Value              0.752419
#               Share of world MVA index                           Value              0.722749
#
# [120 rows x 25 columns]

# %% [markdown]
# ## Plotting

# %%
temp
# Out:
#        dt         Country  AverageTemperature  AverageTemperatureUncertainty
# 0    1990           China           10.930208                       0.331760
# 1    1990         Germany            9.785250                       0.289024
# 2    1990           India           26.033152                       0.395594
# 3    1990           Japan           14.147424                       0.269750
# 4    1990  United Kingdom           10.101881                       0.279119
# ..    ...             ...                 ...                            ...
# 139  2013         Germany            9.141339                       0.279643
# 140  2013           India           27.179701                       0.512657
# 141  2013           Japan           13.804729                       0.450458
# 142  2013  United Kingdom            9.156000                       0.434500
# 143  2013   United States           14.929293                       0.387619
#
# [144 rows x 4 columns]

# %%
india = temp[temp['Country'] == 'India']
japan = temp[temp['Country'] == 'Japan']
uk = temp[temp['Country'] == 'United Kingdom']
usa = temp[temp['Country'] == 'United States']
china = temp[temp['Country'] == 'China']
germany = temp[temp['Country'] == 'Germany']

# %%
dates = india['dt'].to_list()
dates
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
fig, ax = plt.subplots(2, 3, figsize = (20, 10), sharex='col', sharey='row')

ax[0, 0].plot(dates, india['AverageTemperature'], label='India')
ax[0, 0].legend()

ax[0, 1].plot(dates, japan['AverageTemperature'], label='Japan', c='#ff00ff')
ax[0, 1].legend()

ax[0, 2].plot(dates, china['AverageTemperature'], label='China', c='#3366ff')
ax[0, 2].legend()

ax[1, 0].plot(dates, usa['AverageTemperature'], label='USA', c='red')
ax[1, 0].legend()

ax[1, 1].plot(dates, uk['AverageTemperature'], label='UK', c='black')
ax[1, 1].legend()

ax[1, 2].plot(dates, germany['AverageTemperature'], label='Germany', c='#00ff00')
ax[1, 2].legend()

# %%
co2 = co2_g.reset_index()
co2 = co2.rename(columns={'Entity':'Country'})
co2
# Out:
#      Year         Country  Annual CO2 emissions (tonnes )
# 0    1990           China                    2.420302e+09
# 1    1990         Germany                    1.012902e+09
# 2    1990           India                    6.165791e+08
# 3    1990           Japan                    1.155263e+09
# 4    1990  United Kingdom                    6.010676e+08
# ..    ...             ...                             ...
# 139  2013         Germany                    8.326430e+08
# 140  2013           India                    1.997879e+09
# 141  2013           Japan                    1.314070e+09
# 142  2013  United Kingdom                    4.777326e+08
# 143  2013   United States                    5.519613e+09
#
# [144 rows x 3 columns]

# %%
india_co2 = co2[co2['Country'] == 'India']
japan_co2 = co2[co2['Country'] == 'Japan']
uk_co2= co2[co2['Country'] == 'United Kingdom']
usa_co2 = co2[co2['Country'] == 'United States']
china_co2 = co2[co2['Country'] == 'China']
germany_co2 = co2[co2['Country'] == 'Germany']

# %%
fig, ax = plt.subplots(2, 3, figsize = (20, 10), sharex='col', sharey='row')

ax[0, 0].plot(dates, india_co2['Annual CO2 emissions (tonnes )'], label='India')
ax[0, 0].legend()

ax[0, 1].plot(dates, japan_co2['Annual CO2 emissions (tonnes )'], label='Japan', c='#ff00ff')
ax[0, 1].legend()

ax[0, 2].plot(dates, china_co2['Annual CO2 emissions (tonnes )'], label='China', c='#3366ff')
ax[0, 2].legend()

ax[1, 0].plot(dates, usa_co2['Annual CO2 emissions (tonnes )'], label='USA', c='red')
ax[1, 0].legend()

ax[1, 1].plot(dates, uk_co2['Annual CO2 emissions (tonnes )'], label='UK', c='black')
ax[1, 1].legend()

ax[1, 2].plot(dates, germany_co2['Annual CO2 emissions (tonnes )'], label='Germany', c='#00ff00')
ax[1, 2].legend()

# %%
#plotting the correlation matrix for all countries

# %%
india_temp_co2 = pd.concat([india,india_co2['Annual CO2 emissions (tonnes )']], axis=1, keys=['india', 'india_co2'])

# %%
india_temp_co2.corr()
# Out:
#                                              india                     \
#                                                 dt AverageTemperature
# india     dt                              1.000000           0.662429
#           AverageTemperature              0.662429           1.000000
#           AverageTemperatureUncertainty   0.482627           0.445901
# india_co2 Annual CO2 emissions (tonnes )  0.966096           0.643293
#
#                                                                         \
#                                          AverageTemperatureUncertainty
# india     dt                                                  0.482627
#           AverageTemperature                                  0.445901
#           AverageTemperatureUncertainty                       1.000000
# india_co2 Annual CO2 emissions (tonnes )                      0.518580
#
#                                                               india_co2
#                                          Annual CO2 emissions (tonnes )
# india     dt                                                   0.966096
#           AverageTemperature                                   0.643293
#           AverageTemperatureUncertainty                        0.518580
# india_co2 Annual CO2 emissions (tonnes )                       1.000000

# %% [markdown]
# We see that for India, date is slightly linear(0.66) with average temperature but highly linear(0.97) with annual co2 emissions, average temperature is slightly linear(0.64) with annual co2 emissions.

# %%
scatter_matrix(india_temp_co2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b862d880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b5cf3280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b5bad700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b4c23b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b4facf70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b4d7a670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b4d7a760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b4aeef40>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b42e8df0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b16135b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b145dd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b37364f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b3536c70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b1869430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b1905bb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b067d370>]],
#       dtype=object)

# %%
japan_temp_co2 = pd.concat([japan,japan_co2['Annual CO2 emissions (tonnes )']], axis=1, keys=['japan', 'japan_co2'])

# %%
japan_temp_co2.corr()
# Out:
#                                              japan                     \
#                                                 dt AverageTemperature
# japan     dt                              1.000000           0.163139
#           AverageTemperature              0.163139           1.000000
#           AverageTemperatureUncertainty   0.377753           0.183885
# japan_co2 Annual CO2 emissions (tonnes )  0.602121          -0.007864
#
#                                                                         \
#                                          AverageTemperatureUncertainty
# japan     dt                                                  0.377753
#           AverageTemperature                                  0.183885
#           AverageTemperatureUncertainty                       1.000000
# japan_co2 Annual CO2 emissions (tonnes )                      0.307771
#
#                                                               japan_co2
#                                          Annual CO2 emissions (tonnes )
# japan     dt                                                   0.602121
#           AverageTemperature                                  -0.007864
#           AverageTemperatureUncertainty                        0.307771
# japan_co2 Annual CO2 emissions (tonnes )                       1.000000

# %% [markdown]
# We see that for Japan, date is slightly linear(0.60) with annual co2 emissions, not much correlation with average temperature, average temperature does not show a linear trend with anything.

# %%
scatter_matrix(japan_temp_co2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c68aa460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c667f370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6472a60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6261220>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c616e9a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a1e780a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a1e78190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a1d76970>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a164f820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a12c8fa0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29d85f760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2bb877ee0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ba2db8b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ba0227c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6d943d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c682b280>]],
#       dtype=object)

# %%
uk_temp_co2 = pd.concat([uk,uk_co2['Annual CO2 emissions (tonnes )']], axis=1, keys=['uk', 'uk_co2'])

# %%
uk_temp_co2.corr()
# Out:
#                                              uk                     \
#                                              dt AverageTemperature
# uk     dt                              1.000000           0.131128
#        AverageTemperature              0.131128           1.000000
#        AverageTemperatureUncertainty   0.284982          -0.243173
# uk_co2 Annual CO2 emissions (tonnes ) -0.845561           0.027289
#
#                                                                      \
#                                       AverageTemperatureUncertainty
# uk     dt                                                  0.284982
#        AverageTemperature                                 -0.243173
#        AverageTemperatureUncertainty                       1.000000
# uk_co2 Annual CO2 emissions (tonnes )                     -0.442839
#
#                                                               uk_co2
#                                       Annual CO2 emissions (tonnes )
# uk     dt                                                  -0.845561
#        AverageTemperature                                   0.027289
#        AverageTemperatureUncertainty                       -0.442839
# uk_co2 Annual CO2 emissions (tonnes )                       1.000000

# %% [markdown]
# We see that for UK, date is negatively and linearly correlated with annual co2 emissions(-0.84), not much with average temperature, average temperature doesn't show a good trend with anything.

# %%
scatter_matrix(uk_temp_co2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2afef53a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b642d490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2afc1c4c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ae95bbe0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ae5f83a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2af16aa60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2af16ab50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2aee3d370>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ade3f220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2adc4c9a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2acf32160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2acd418e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2acb24100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2cc291820>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2cbe6afa0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2cb5cd760>]],
#       dtype=object)

# %%
usa_temp_co2 = pd.concat([usa,usa_co2['Annual CO2 emissions (tonnes )']], axis=1, keys=['usa', 'usa_co2'])

# %%
usa_temp_co2.corr()
# Out:
#                                              usa                     \
#                                               dt AverageTemperature
# usa     dt                              1.000000           0.537105
#         AverageTemperature              0.537105           1.000000
#         AverageTemperatureUncertainty   0.498608           0.689160
# usa_co2 Annual CO2 emissions (tonnes )  0.469275           0.109526
#
#                                                                       \
#                                        AverageTemperatureUncertainty
# usa     dt                                                  0.498608
#         AverageTemperature                                  0.689160
#         AverageTemperatureUncertainty                       1.000000
# usa_co2 Annual CO2 emissions (tonnes )                     -0.143728
#
#                                                               usa_co2
#                                        Annual CO2 emissions (tonnes )
# usa     dt                                                   0.469275
#         AverageTemperature                                   0.109526
#         AverageTemperatureUncertainty                       -0.143728
# usa_co2 Annual CO2 emissions (tonnes )                       1.000000

# %% [markdown]
# We see that for USA, there is no much linear relationship for average temperature and co2 emissions with date, and average temperatue does not show any trend with respect to annual co2 emissions

# %%
scatter_matrix(usa_temp_co2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c8bd60d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c82c0310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c7772a00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c75eb1c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6def940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6d47160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c68e8130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6a9d910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c65fa7c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a1ccaf40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a15a6700>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29d9e9e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb29ee38640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29e35adc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2bbd44580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b91acd00>]],
#       dtype=object)

# %%
china_temp_co2 = pd.concat([china,china_co2['Annual CO2 emissions (tonnes )']], axis=1, keys=['china', 'china_co2'])

# %%
china_temp_co2.corr()
# Out:
#                                              china                     \
#                                                 dt AverageTemperature
# china     dt                              1.000000           0.296880
#           AverageTemperature              0.296880           1.000000
#           AverageTemperatureUncertainty   0.519485           0.339821
# china_co2 Annual CO2 emissions (tonnes )  0.940295           0.222458
#
#                                                                         \
#                                          AverageTemperatureUncertainty
# china     dt                                                  0.519485
#           AverageTemperature                                  0.339821
#           AverageTemperatureUncertainty                       1.000000
# china_co2 Annual CO2 emissions (tonnes )                      0.623769
#
#                                                               china_co2
#                                          Annual CO2 emissions (tonnes )
# china     dt                                                   0.940295
#           AverageTemperature                                   0.222458
#           AverageTemperatureUncertainty                        0.623769
# china_co2 Annual CO2 emissions (tonnes )                       1.000000

# %% [markdown]
# We see that for China, date is highly linear(0.94) with annual co2 emissions, very similar to India, not much trend with average temperature, average temperature and annual co2 emissions are also not showing a linear trend.

# %%
scatter_matrix(china_temp_co2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ba479040>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ad27a370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2ca54b6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c7ddbe20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c6fdf5e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29d57dca0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29d57dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b9f9e5b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b0340460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c9c64be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2b0ec03a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c73f2b20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2c5c5a2e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a784aa60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a6279220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2918479a0>]],
#       dtype=object)

# %%
germany_temp_co2 = pd.concat([germany, germany_co2['Annual CO2 emissions (tonnes )']], axis=1, keys=['germany', 'germany_co2'])

# %%
germany_temp_co2.corr()
# Out:
#                                              germany                     \
#                                                   dt AverageTemperature
# germany     dt                              1.000000           0.137862
#             AverageTemperature              0.137862           1.000000
#             AverageTemperatureUncertainty  -0.044270           0.116005
# germany_co2 Annual CO2 emissions (tonnes ) -0.957389          -0.217959
#
#                                                                           \
#                                            AverageTemperatureUncertainty
# germany     dt                                                 -0.044270
#             AverageTemperature                                  0.116005
#             AverageTemperatureUncertainty                       1.000000
# germany_co2 Annual CO2 emissions (tonnes )                      0.086034
#
#                                                               germany_co2
#                                            Annual CO2 emissions (tonnes )
# germany     dt                                                  -0.957389
#             AverageTemperature                                  -0.217959
#             AverageTemperatureUncertainty                        0.086034
# germany_co2 Annual CO2 emissions (tonnes )                       1.000000

# %% [markdown]
# We see that for Germany, date is negatively and linearly correlated with annual co2 emissions(-0.957), not much with average temperature, average temperature doesn't show a good trend with anything, it shows a slighly negative correlation with annual co2 emissions, but not linear.

# %%
scatter_matrix(germany_temp_co2, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb296053ca0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29607a7c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2960a5d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb298542430>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb29856bbb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2985a12b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2985a13a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2985c9b80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb29bf87a30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb29bfbc1f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a0038970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a0127130>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a01508b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a01970d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a02257f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb2a028ef70>]],
#       dtype=object)
